# %% [markdown]
# ## DATA VISUALIZATION AND DATA ANALYSIS

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('WSN.csv')
df.head()
# Out:
#        id   Time   Is_CH   who CH   Dist_To_CH   ADV_S   ADV_R   JOIN_S  \
# 0  101000     50       1   101000      0.00000       1       0        0
# 1  101001     50       0   101044     75.32345       0       4        1
# 2  101002     50       0   101010     46.95453       0       4        1
# 3  101003     50       0   101044     64.85231       0       4        1
# 4  101004     50       0   101010      4.83341       0       4        1
#
#     JOIN_R   SCH_S   SCH_R  Rank   DATA_S   DATA_R   Data_Sent_To_BS  \
# 0       25       1       0     0        0     1200                48
# 1        0       0       1     2       38        0                 0
# 2        0       0       1    19       41        0                 0
# 3        0       0       1    16       38        0                 0
# 4        0       0       1    25       41        0                 0
#
#     dist_CH_To_BS   send_code   Expaned Energy Attack type
# 0       130.08535            0         2.46940      Normal
# 1         0.00000            4         0.06957      Normal
# 2         0.00000            3         0.06898      Normal
# 3         0.00000            4         0.06673      Normal
# 4         0.00000            3         0.06534      Normal

# %%
df.columns
# Out:
# Index([' id', ' Time', ' Is_CH', ' who CH', ' Dist_To_CH', ' ADV_S', ' ADV_R',
#        ' JOIN_S', ' JOIN_R', ' SCH_S', ' SCH_R', 'Rank', ' DATA_S', ' DATA_R',
#        ' Data_Sent_To_BS', ' dist_CH_To_BS', ' send_code ', 'Expaned Energy',
#        'Attack type'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

var = ['Attack type']
  
for i in var:
    df[i] = le.fit_transform(df[i]).astype(int)

# %%
    sns.countplot(x='Attack type',data=df)
# Out:
# <Axes: xlabel='Attack type', ylabel='count'>

# %%
plt.figure(figsize=(15,5))

plt.subplot(1,2,1)
plt.hist(df['Attack type'],color='red')

plt.subplot(1,2,2)
plt.hist(df['Expaned Energy'],color='blue')
# Out:
# (array([3.74627e+05, 4.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00,
#         0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 3.00000e+01]),
#  array([ 0.      ,  4.509394,  9.018788, 13.528182, 18.037576, 22.54697 ,
#         27.056364, 31.565758, 36.075152, 40.584546, 45.09394 ]),
#  <BarContainer object of 10 artists>)

# %%
df['Expaned Energy'].hist(figsize=(10,5),color='yellow')
# Out:
# <Axes: >

# %%
plt.boxplot(df['Attack type'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x19e45fc0a10>,
#   <matplotlib.lines.Line2D at 0x19e45fc0740>],
#  'caps': [<matplotlib.lines.Line2D at 0x19e45fc0440>,
#   <matplotlib.lines.Line2D at 0x19e45fc0110>],
#  'boxes': [<matplotlib.lines.Line2D at 0x19e478e31a0>],
#  'medians': [<matplotlib.lines.Line2D at 0x19e45f7fdd0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x19e45f7fb00>],
#  'means': []}

# %%
df[' Dist_To_CH'].plot(kind='density')
# Out:
# <Axes: ylabel='Density'>

# %%
sns.displot(df['Attack type'], color='purple') 
# barplot, boxenplot, boxplot, countplot, displot, distplot, ecdfplot, histplot, kdeplot, pointplot, violinplot, stripplot

# %%
sns.displot(df['Expaned Energy'], color='coral') # residplot, scatterplot

# %%
fig, ax = plt.subplots(figsize=(20,15))
sns.heatmap(df.corr(),annot = True, fmt='0.2%',cmap = 'autumn',ax=ax)
# Out:
# <Axes: >

# %% [markdown]
# ## PIECHART

# %%
def plot(df, variable):
    dataframe_pie = df[variable].value_counts()
    ax = dataframe_pie.plot.pie(figsize=(9,9), autopct='%1.2f%%', fontsize = 10)
    ax.set_title(variable + ' \n', fontsize = 10)
    return np.round(dataframe_pie/df.shape[0]*100,2)

plot(df, 'Attack type')
# Out:
# Attack type
# 3    90.77
# 2     3.90
# 0     2.68
# 4     1.77
# 1     0.88
# Name: count, dtype: float64
